# %%
import os
import numpy as np
import pandas as pd
import pickle
import warnings

# %%
file_path='./data/traffic/period-7.csv'
raw_data_path = os.path.join(os.path.dirname(file_path), "raw_data.pickle")

# %%
tem = pd.read_csv(file_path)

# %%
tem
# Out:
#           deliveryPeriodIndex  advertiserNumber  advertiserCategoryIndex  \
# 0                         7.0               0.0                      0.0
# 1                         7.0               1.0                      0.0
# 2                         7.0               2.0                      0.0
# 3                         7.0               3.0                      0.0
# 4                         7.0               4.0                      0.0
# ...                       ...               ...                      ...
# 23998843                  7.0              43.0                      5.0
# 23998844                  7.0              44.0                      5.0
# 23998845                  7.0              45.0                      5.0
# 23998846                  7.0              46.0                      5.0
# 23998847                  7.0              47.0                      5.0
#
#           budget  CPAConstraint  timeStepIndex  remainingBudget  pvIndex  \
# ...

# %%
tem[tem.advertiserNumber==0]
# Out:
#           deliveryPeriodIndex  advertiserNumber  advertiserCategoryIndex  \
# 0                         7.0               0.0                      0.0
# 48                        7.0               0.0                      0.0
# 96                        7.0               0.0                      0.0
# 144                       7.0               0.0                      0.0
# 192                       7.0               0.0                      0.0
# ...                       ...               ...                      ...
# 23998608                  7.0               0.0                      0.0
# 23998656                  7.0               0.0                      0.0
# 23998704                  7.0               0.0                      0.0
# 23998752                  7.0               0.0                      0.0
# 23998800                  7.0               0.0                      0.0
#
#           budget  CPAConstraint  timeStepIndex  remainingBudget  pvIndex  \
# ...

# %%
tem[tem.timeStepIndex==0]
# Out:
#         deliveryPeriodIndex  advertiserNumber  advertiserCategoryIndex  \
# 0                       7.0               0.0                      0.0
# 1                       7.0               1.0                      0.0
# 2                       7.0               2.0                      0.0
# 3                       7.0               3.0                      0.0
# 4                       7.0               4.0                      0.0
# ...                     ...               ...                      ...
# 600763                  7.0              43.0                      5.0
# 600764                  7.0              44.0                      5.0
# 600765                  7.0              45.0                      5.0
# 600766                  7.0              46.0                      5.0
# 600767                  7.0              47.0                      5.0
#
#         budget  CPAConstraint  timeStepIndex  remainingBudget  pvIndex  \
# ...

# %%
tem.pvIndex.value_counts()
# Out:
# 0.0        2304
# 900.0      2304
# 898.0      2304
# 897.0      2304
# 896.0      2304
#            ...
# 24803.0      48
# 24804.0      48
# 24805.0      48
# 24806.0      48
# 26545.0      48
# Name: pvIndex, Length: 26546, dtype: int64

# %%
tem.advertiserNumber.value_counts()
# Out:
# 0.0     499976
# 1.0     499976
# 26.0    499976
# 27.0    499976
# 28.0    499976
# 29.0    499976
# 30.0    499976
# 31.0    499976
# 32.0    499976
# 33.0    499976
# 34.0    499976
# 35.0    499976
# 36.0    499976
# 37.0    499976
# 38.0    499976
# 39.0    499976
# 40.0    499976
# 41.0    499976
# 42.0    499976
# 43.0    499976
# 44.0    499976
# 45.0    499976
# 46.0    499976
# 25.0    499976
# 24.0    499976
# 23.0    499976
# 11.0    499976
# 2.0     499976
# 3.0     499976
# 4.0     499976
# 5.0     499976
# 6.0     499976
# 7.0     499976
# 8.0     499976
# 9.0     499976
# 10.0    499976
# 12.0    499976
# 22.0    499976
# 13.0    499976
# 14.0    499976
# 15.0    499976
# 16.0    499976
# 17.0    499976
# 18.0    499976
# 19.0    499976
# 20.0    499976
# 21.0    499976
# 47.0    499976
# Name: advertiserNumber, dtype: int64
